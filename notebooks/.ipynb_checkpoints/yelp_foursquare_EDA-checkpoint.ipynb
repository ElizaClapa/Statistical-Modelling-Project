# %%
# imports

# %% [markdown]
# # Foursquare

# %% [markdown]
# ## 1. Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
import requests
import os
import pandas as pd
from pprint import pprint

# Get locations (latitude, longitude) for each station in Queretaro, Mexico.
response = requests.get("http://api.citybik.es/v2/networks/qrobici")
data = response.json()

# Make an empty dictionary to save all the information retrieved from the JSON response when going through the loop. 
stations_coor = []

for station in data['network']['stations']:
        latitude = station['latitude']
        longitude = station['longitude']
        
        stations_coor.append({
            'Latitute': latitude,
            'Longitude': longitude
        })

stations_coor = pd.DataFrame(stations_coor) #Information to use to obtain restaurants or bars from Foursquare

# %%
# Api Key
api_key = os.environ["FOURSQUARE_API_KEY_ZSH"]

# %%
# Converting the stations_coor DataFrame to a list, then formatting to match the URL requirements from the Foursquare API: 
stations_coor_list = stations_coor.values.tolist()
stations_coor_list_rounded = [[round(x, 2) for x in coord] for coord in stations_coor_list]
geocodes = [f'{coord[0]},{coord[1]}' for coord in stations_coor_list_rounded]

# Defining a function to get the get request giving a coordinate from geocodes
def find_restaurants(geocodes):
    url = "https://api.foursquare.com/v3/places/search?query=restaurant&radius=1000&fields=name,hours,rating,popularity,price,distance,tips&ll="
    headers = {"accept": "application/json"}
    headers['Authorization'] = api_key
    response = requests.get(url=url+geocodes, headers = headers) 
    data = response.json()
    return data

# Create an empty list to append the information obtained from the find_restaurants function for each of the geocode pairs from geocodes. 
restaurants_list = []

for geocode in geocodes: 
    data = find_restaurants(geocode)
    restaurants_list.append(data)

# %%
# Saving and loading information into files with JSON
import json
with open('data2.json', 'w') as f:
    json.dump(restaurants_list, f)

with open('data2.json', 'r') as f:
    saved_restaurants_list = json.loads(f.read())

pprint(saved_restaurants_list)
# Out:
# [{'context': {'geo_bounds': {'circle': {'center': {'latitude': 20.58,
#                                                    'longitude': -100.41},
#                                         'radius': 1000}}},
#   'results': [{'distance': 47,
#                'hours': {'display': 'Tue 13:00-22:00; Wed 13:00-22:30; Thu-Sat '
#                                     '13:00-23:00; Sun 13:00-20:30',
#                          'is_local_holiday': False,
#                          'open_now': True,
#                          'regular': [{'close': '2200',
#                                       'day': 2,
#                                       'open': '1300'},
#                                      {'close': '2230',
#                                       'day': 3,
#                                       'open': '1300'},
#                                      {'close': '2300',
#                                       'day': 4,
#                                       'open': '1300'},
#                                      {'close': '2300',
#                                       'day': 5,
#                                       'open': '1300'},
#                                      {'close': '2300',
#                                       'day': 6,
#                                       'open': '1300'},
#                                      {'close': '2030',
#                                       'day': 7,
#                                       'open': '1300'}]},
#                'name': 'Monosabio Hamburguesería',
#                'popularity': 0.9796487897484575,
#                'price': 3,
#                'rating': 8.5,
#                'tips': [{'created_at': '2022-09-04T02:12:22.000Z',
#                          'text': 'Honestamente no esperaba mucho ya que en '
#                                  'general la comida de Querétaro me parece '
#                                  'mala peeero wow, me encantó la hamburguesa 🤩 '
#                                  'recomendable'},
#                         {'created_at': '2020-12-29T01:13:52.000Z',
#                          'text': 'Las calidad de cada ingrediente: quesos, '
#                                  'carne, pan es increíble!! Las cervezas '
#                                  'deliciosas y el personal súper atento'},
#                         {'created_at': '2020-10-04T02:15:10.000Z',
#                          'text': 'Está muy bien el lugar las hamburguesas '
#                                  'tienen buen sabor y buena presentación y el '
#                                  'ambiente del lugar es muy agradable, la '
#                                  'atención es buena y rápida'},
#                         {'created_at': '2020-03-04T22:49:24.000Z',
#                          'text': 'Buenísima! Excelente lugar y servicio!'},
#                         {'created_at': '2019-08-28T20:11:10.000Z',
#                          'text': 'Deliciosas Hamburguesas, algo elevadas en '
#                                  'precio. Lugar muy agradable.'}]},
#               {'distance': 149,
#                'hours': {'display': 'Open Daily 0:00-4:00',
#                          'is_local_holiday': False,
#                          'open_now': True,
#                          'regular': [{'close': '0400',
#                                       'day': 1,
#                                       'open': '0000'},
#                                      {'close': '+0000',
#                                       'day': 1,
#                                       'open': '1400'},
#                                      {'close': '0400',
#                                       'day': 2,
#                                       'open': '0000'},
#                                      {'close': '+0000',
#                                       'day': 2,
#                                       'open': '1400'},
#                                      {'close': '0400',
#                                       'day': 3,
#                                       'open': '0000'},
#                                      {'close': '+0000',
#                                       'day': 3,
#                                       'open': '1400'},
#                                      {'close': '0400',
#                                       'day': 4,
#                                       'open': '0000'},
#                                      {'close': '+0000',
#                                       'day': 4,
#                                       'open': '1400'},
#                                      {'close': '0400',
#                                       'day': 5,
#                                       'open': '0000'},
#                                      {'close': '+0000',
#                                       'day': 5,
#                                       'open': '1400'},
#                                      {'close': '0400',
#                                       'day': 6,
#                                       'open': '0000'},
#                                      {'close': '+0000',
#                                       'day': 6,
#                                       'open': '1400'},
#                                      {'close': '0400',
#                                       'day': 7,
#                                       'open': '0000'},
#                                      {'close': '+0000',
#                                       'day': 7,
#                                       'open': '1400'}]},
#                'name': 'Taqueria Jalisco',
#                'popularity': 0.9372757475083057,
#                'price': 1,
#                'rating': 7.9,
#                'tips': [{'created_at': '2023-01-11T15:23:58.000Z',
#                          'text': 'Los tacos de pastor dorados!'},
#                         {'created_at': '2020-10-21T03:27:55.000Z',
#                          'text': 'Atienden muy rápido y los tacos son muy '
#                                  'buenos 👍'},
#                         {'created_at': '2019-11-22T23:00:37.000Z',
#                          'text': 'Buenísimos los tacos, sobre todo los de '
#                                  'suadero. Es barato. Si están cerca son muy '
#                                  'recomendables.'},
#                         {'created_at': '2019-11-11T14:51:28.000Z',
#                          'text': 'Todos están muy buenos!! Pastor, suadero, '
#                                  'costilla, lengua, son de los mejores que he '
#                                  'comido 👌🏻👌🏻👌🏻 dan muy buen servicio y muy '
#                                  'rápidos.'},
#                         {'created_at': '2019-09-11T23:00:36.000Z',
#                          'text': 'Todo, me encantan esos tacos y atienden '
#                                  'rápido'}]},
#               {'distance': 143,
#                'hours': {'is_local_holiday': False, 'open_now': False},
#                'name': 'Taqueria la Jalisciense',
#                'popularity': 0.8927954437588989,
#                'price': 1,
#                'rating': 7.7,
#                'tips': [{'created_at': '2021-03-14T04:19:56.000Z',
#                          'text': 'El pastor y el queso'},
#                         {'created_at': '2021-03-14T04:19:41.000Z',
#                          'text': 'El pastor y el queso delicioso'},
#                         {'created_at': '2018-04-12T07:14:18.000Z',
#                          'text': 'definitivamente sí son de los mejorcitos en '
#                                  'Querétaro ❤️ pero sólo los de lengua y tripa '
#                                  'doradita'},
#                         {'created_at': '2017-10-04T06:21:53.000Z',
#                          'text': 'Ufff, probé todos en una sentada, son muy '
#                                  'chiquitos así que no se espanten jejeje, mi '
#                                  'favorito fue el de lengua y costilla... las '
#                                  'salsas son muy ricas con el picor exacto a '
#                                  'mi gusto.'},
#                         {'created_at': '2017-06-02T14:33:18.000Z',
#                          'text': 'Los tacos muy ricos, de los mejores aquí en '
#                                  'Querétaro'}]},
#               {'distance': 158,
#                'hours': {'display': 'Tue-Sat 12:30-22:00; Sun 12:30-20:00',
#                          'is_local_holiday': False,
#                          'open_now': True,
#                          'regular': [{'close': '2200',
#                                       'day': 2,
#                                       'open': '1230'},
#                                      {'close': '2200',
#                                       'day': 3,
#                                       'open': '1230'},
#                                      {'close': '2200',
#                                       'day': 4,
#                                       'open': '1230'},
#                                      {'close': '2200',
#                                       'day': 5,
#                                       'open': '1230'},
#                                      {'close': '2200',
#                                       'day': 6,
#                                       'open': '1230'},
#                                      {'close': '2000',
#                                       'day': 7,
#                                       'open': '1230'}]},
#                'name': 'Los Idolos',
#                'popularity': 0.941186521120076,
#                'price': 1,
#                'rating': 7.7,
#                'tips': [{'created_at': '2021-08-22T20:24:26.000Z',
#                          'text': 'El chori! Y la milanesa! No se pueden '
#                                  'perder!'},
#                         {'created_at': '2021-08-22T20:23:23.000Z',
#                          'text': 'El servicio es muy bueno y la comida es '
#                                  'simplemente diferente. Muy bueno todo!'},
#                         {'created_at': '2020-09-18T22:17:26.000Z',
#                          'text': 'La comida excelente, buen sabor, bien '
#                                  'servido todo, muy vasto y a buenos precios. '
#                                  'El pero es la atención, no tienen actitud de '
#                                  'servicio, tache ahí.'},
#                         {'created_at': '2019-11-09T21:38:50.000Z',
#                          'text': 'La de tocino 🥓 mmmmmm'},
#                         {'created_at': '2019-06-30T00:22:27.000Z',
#                          'text': 'Pizzas 🍕, choripanes, ensaladas 🥗, empanadas '
#                                  'y cervezas 🍺 buena atención a buen '
#                                  'precio.'}]},
#               {'distance': 243,
#                'hours': {'display': 'Mon-Sat 13:00-22:00; Sun 13:00-21:00',
#                          'is_local_holiday': False,
#                          'open_now': True,
#                          'regular': [{'close': '2200',
#                                       'day': 1,
#                                       'open': '1300'},
#                                      {'close': '2200',
#                                       'day': 2,
#                                       'open': '1300'},
#                                      {'close': '2200',
#                                       'day': 3,
#                                       'open': '1300'},
#                                      {'close': '2200',
#                                       'day': 4,
#                                       'open': '1300'},
#                                      {'close': '2200',
#                                       'day': 5,
#                                       'open': '1300'},
#                                      {'close': '2200',
#                                       'day': 6,
#                                       'open': '1300'},
#                                      {'close': '2100',
#                                       'day': 7,
#                                       'open': '1300'}]},
#                'name': 'Fogon do Brasil Queretaro',
#                'popularity': 0.9894826767916469,
#                'price': 2,
#                'rating': 8.2,
#                'tips': [{'created_at': '2021-10-31T00:46:52.000Z',
#                          'text': 'Todo rico y el servicio muy bueno'},
#                         {'created_at': '2020-01-04T01:18:36.000Z',
#                          'text': 'La barra de ensaladas!'},
#                         {'created_at': '2019-12-30T20:34:59.000Z',
#                          'text': 'Esta bien el lugar sólo que en las pantallas '
#                                  'ponen novelas de televisa. :D buen detalle'},
#                         {'created_at': '2019-09-27T02:31:25.000Z',
#                          'text': 'Excelente servicio y la comida de primer '
#                                  'nivel a un costo accesible 👏🏼'},
#                         {'created_at': '2019-09-26T20:59:14.000Z',
#                          'text': 'Servicio y atención buena, en lo personal el '
#                                  'servicio de espadas fue lento en nuestra '
#                                  'mesa y ofrecieron pocos cortes 👎🏻'}]},
#               {'distance': 231,
#                'hours': {'is_local_holiday': False, 'open_now': False},
#                'name': 'Taqueria y Parrillada Chapala',
#                'popularity': 0.9893877551020408,
#                'price': 1,
#                'rating': 7.8,
#                'tips': [{'created_at': '2017-07-22T02:54:47.000Z',
#                          'text': 'Muy rico todo. La arrachera muy buena. Los '
#                                  'tacos de tripa también'},
#                         {'created_at': '2017-06-03T16:10:34.000Z',
#                          'text': 'Muy rico, bien servido y buen servicio, les '
#                                  'recomiendo los frijoles charros. 😉'},
#                         {'created_at': '2016-08-13T01:02:46.000Z',
#                          'text': 'Todo muy bueno. Las gringas,  Tortas de '
#                                  'pastor, alambres y demás.'},
#                         {'created_at': '2015-12-28T01:45:00.000Z',
#                          'text': 'Riquísimo. Barato y muy a gusto. 👌'}]},
#               {'distance': 514,
#                'hours': {'is_local_holiday': False, 'open_now': False},
#                'name': 'Tacos Memo',
#                'popularity': 0.04039867109634551,
#                'price': 1,
#                'rating': 8.6,
#                'tips': [{'created_at': '2017-05-18T03:40:20.000Z',
#                          'text': 'Muy rica la comida y todo hecho a mano 👌'},
#                         {'created_at': '2017-03-21T02:50:27.000Z',
#                          'text': 'El sope especial de Pastor sin salsa es '
#                                  'delicioso para quienes no comen Chile ♡'},
#                         {'created_at': '2016-12-31T02:45:55.000Z',
#                          'text': 'No esperes pagar lo de un sope normal y '
#                                  'tampoco esperes un sope normal,  estos son '
#                                  'deliciosos,  "verde, doradito y con '
#                                  'pastor".'},
#                         {'created_at': '2015-10-29T01:39:31.000Z',
#                          'text': 'Los sopes especiales con la salsa de los '
#                                  'tacos <3'},
#                         {'created_at': '2015-08-10T09:02:14.000Z',
#                          'text': 'Váyanse haciendo hambre se tardan un rato '
#                                  'pero valen mucho la pena'}]},
#               {'distance': 516,
#                'hours': {'is_local_holiday': False, 'open_now': False},
#                'name': "Carl's jr Esfera",
#                'popularity': 0.9173991457047935,
#                'price': 1,
#                'rating': 8.5,
#                'tips': [{'created_at': '2019-03-15T22:03:03.000Z',
#                          'text': 'The veggie burger'},
#                         {'created_at': '2018-02-23T20:24:33.000Z',
#                          'text': 'No demasiado rico pero todo normal'},
#                         {'created_at': '2017-12-17T22:46:38.000Z',
#                          'text': 'Comida rica sin embargo mal servicio. No '
#                                  'pagan el cambio completo y constantemente '
#                                  'apresuran  la gente levantando la mesa, '
#                                  'incluso cuando es obvio que no has terminado '
#                                  'de comer.'},
#                         {'created_at': '2017-09-27T19:10:37.000Z',
#                          'text': 'Combos ricos mejor que macdonals!!😄'},
#                         {'created_at': '2017-09-27T19:09:30.000Z',
#                          'text': 'Mis hamburguesas favoritas!!! Y ests semana '
#                                  'combos 😁'}]},
#               {'distance': 598,
#                'hours': {'display': 'Mon-Thu 13:00-23:00; Fri-Sat 13:00-24:00; '
#                                     'Sun 13:00-22:00',
#                          'is_local_holiday': False,
#                          'open_now': True,
#                          'regular': [{'close': '2300',
#                                       'day': 1,
#                                       'open': '1300'},
#                                      {'close': '2300',
#                                       'day': 2,
#                                       'open': '1300'},
#                                      {'close': '2300',
#                                       'day': 3,
#                                       'open': '1300'},
#                                      {'close': '2300',
#                                       'day': 4,
#                                       'open': '1300'},
#                                      {'close': '+0000',
#                                       'day': 5,
#                                       'open': '1300'},
#                                      {'close': '+0000',
#                                       'day': 6,
#                                       'open': '1300'},
#                                      {'close': '2200',
#                                       'day': 7,
#                                       'open': '1300'}]},
#                'name': 'Sushi Roll',
#                'popularity': 0.9878120550545799,
#                'price': 2,
#                'rating': 8.2,
#                'tips': [{'created_at': '2019-05-08T19:11:35.000Z',
#                          'text': 'La comida y el lugar están bien sin embargo '
#                                  'no hay wi fi pésimo.'},
#                         {'created_at': '2019-03-30T21:54:55.000Z',
#                          'text': 'Es lento lento lento el servicio'},
#                         {'created_at': '2018-12-13T03:30:49.000Z',
#                          'text': 'En noches de sushi lleguen temprano porque '
#                                  'la espera es muuuuucha'},
#                         {'created_at': '2018-12-03T01:18:56.000Z',
#                          'text': 'La Victoria en michelada Cubana es la '
#                                  'mejor!! 🍺👌🏻'},
#                         {'created_at': '2018-07-22T19:54:03.000Z',
#                          'text': 'Rockefeller roll, riquísimo!!'}]},
#               {'distance': 566,
#                'hours': {'display': 'Mon-Thu 13:00-23:00; Fri 13:00-24:00; Sat '
#                                     '12:00-24:00; Sun 12:00-22:00',
#                          'is_local_holiday': False,
#                          'open_now': True,
#                          'regular': [{'close': '2300',
#                                       'day': 1,
#                                       'open': '1300'},
#                                      {'close': '2300',
#                                       'day': 2,
#                                       'open': '1300'},
#                                      {'close': '2300',
#                                       'day': 3,
#                                       'open': '1300'},
#                                      {'close': '2300',
#                                       'day': 4,
#                                       'open': '1300'},
#                                      {'close': '+0000',
#                                       'day': 5,
#                                       'open': '1300'},
#                                      {'close': '+0000',
#                                       'day': 6,
#                                       'open': '1200'},
#                                      {'close': '2200',
#                                       'day': 7,
#                                       'open': '1200'}]},
#                'name': 'California Pizza Kitchen',
#                'popularity': 0.9670242050308495,
#                'price': 1,
#                'rating': 7.8,
#                'tips': [{'created_at': '2023-07-13T02:48:42.000Z',
#                          'text': 'Dejo de existir 🤷🏻\u200d♂️'},
#                         {'created_at': '2023-06-03T22:16:08.000Z',
#                          'text': 'Nunca tienen abierto al 100 ahorita que '
#                                  'estamos 33 grados y no tienen clima y ni '
#                                  'Baños  , ya es la 4 ta ves que vengo y no '
#                                  'han reparado y pésima actitud'},
#                         {'created_at': '2023-03-28T00:59:16.000Z',
#                          'text': 'Las pizzas son excelentes.'},
#                         {'created_at': '2022-01-02T21:17:02.000Z',
#                          'text': 'Ensalada Thai deliciosa! La personal ya es '
#                                  'MUY grande!'},
#                         {'created_at': '2021-10-07T19:48:39.000Z',
#                          'text': 'Nice place with delicious meal it was nice '
#                                  'being there long ago'}]}]},
#  {'context': {'geo_bounds': {'circle': {'center': {'latitude': 20.58,
#                                                    'longitude': -100.4},
#                                         'radius': 1000}}},
#   'results': [{'distance': 167,
#                'hours': {'display': 'Mon-Fri 7:00-23:59; Sat 00:00-1:00, '
#                                     '7:00-23:59; Sun 00:00-1:00, 7:00-23:00',
#                          'is_local_holiday': False,
#                          'open_now': True,
#                          'regular': [{'close': '2359',
#                                       'day': 1,
#                                       'open': '0700'},
#                                      {'close': '2359',
#                                       'day': 2,
#                                       'open': '0700'},
#                                      {'close': '2359',
#                                       'day': 3,
#                                       'open': '0700'},
#                                      {'close': '2359',
#                                       'day': 4,
#                                       'open': '0700'},
#                                      {'close': '2359',
#                                       'day': 5,
#                                       'open': '0700'},
#                                      {'close': '0100',
#                                       'day': 6,
#                                       'open': '0000'},
#                                      {'close': '2359',
#                                       'day': 6,
#                                       'open': '0700'},
#                                      {'close': '0100',
#                                       'day': 7,
#                                       'open': '0000'},
#                                      {'close': '2300',
#                                       'day': 7,
#                                       'open': '0700'}]},
#                'name': 'Parrilla Leonesa',
#                'popularity': 0.9900142382534409,
#                'price': 1,
#                'rating': 8.3,
#                'tips': [{'created_at': '2022-05-29T19:06:50.000Z',
#                          'text': 'Sopa de tortilla y la parrillada leonesa muy '
#                                  'buenas'},
#                         {'created_at': '2021-12-01T15:03:37.000Z',
#                          'text': 'El filete y los tacos  de arrachera están '
#                                  'muy buenos'},
#                         {'created_at': '2021-04-06T01:35:06.000Z',
#                          'text': 'Los tacos de pastor son los mejores.'},
#                         {'created_at': '2021-03-10T03:03:45.000Z',
#                          'text': 'Es de los primeros restaurantes que conocí '
#                                  'desde pequeño pero algo ha pasa que la '
#                                  'calidad y el sabor cambiaron un poco ojalá '
#                                  'vuelvan porque es excelente y sobre todo el '
#                                  'servicio 🙂'},
#                         {'created_at': '2021-02-07T03:01:50.000Z',
#                          'text': 'En gral buen servicio y buenos alimentos'}]},
#               {'distance': 290,
#                'hours': {'display': 'Mon-Fri 13:30-23:59; Sat 00:00-23:59; Sun '
#                                     '00:00-22:00',
#                          'is_local_holiday': False,
#                          'open_now': True,
#                          'regular': [{'close': '2359',
#                                       'day': 1,
#                                       'open': '1330'},
#                                      {'close': '2359',
#                                       'day': 2,
#                                       'open': '1330'},
#                                      {'close': '2359',
#                                       'day': 3,
#                                       'open': '1330'},
#                                      {'close': '2359',
#                                       'day': 4,
#                                       'open': '1330'},
#                                      {'close': '2359',
#                                       'day': 5,
#                                       'open': '1330'},
#                                      {'close': '0100',
#                                       'day': 6,
#                                       'open': '0000'},
#                                      {'close': '2359',
#                                       'day': 6,
#                                       'open': '1330'},
#                                      {'close': '0100',
#                                       'day': 7,
#                                       'open': '0000'},
#                                      {'close': '2200',
#                                       'day': 7,
#                                       'open': '1330'}]},
#                'name': 'iL Diavolo',
#                'popularity': 0.9873943996203133,
#                'price': 2,
#                'rating': 8.9,
#                'tips': [{'created_at': '2024-02-03T03:58:10.000Z',
#                          'text': 'Excelente lugar para cenar y leer'},
#                         {'created_at': '2023-02-22T18:49:20.000Z',
#                          'text': 'Las pizzas a la leña y la lasagna es de lo '
#                                  'más recomendable. Las bebidas sin alcohol de '
#                                  'pepino y menta y frutos rojos también son '
#                                  'buenas para acompañar la comida.'},
#                         {'created_at': '2023-02-06T23:46:28.000Z',
#                          'text': 'personnel very friendly. Very good option'},
#                         {'created_at': '2021-05-21T17:55:44.000Z',
#                          'text': 'Las pizzas, las ensaladas y el servicio son '
#                                  'muy buenos'},
#                         {'created_at': '2019-09-28T22:17:56.000Z',
#                          'text': 'Chuletón de Cerdo!!!'}]},
#               {'distance': 213,
#                'hours': {'display': 'Mon 13:00-23:59; Tue 00:00-11:00, '
#                                     '13:00-23:59; Wed-Thu 00:00-12:00, '
#                                     '13:00-23:59; Fri-Sat 00:00-23:59; Sun '
#                                     '00:00-21:00',
#                          'is_local_holiday': False,
#                          'open_now': True,
#                          'regular': [{'close': '2359',
#                                       'day': 1,
#                                       'open': '1300'},
#                                      {'close': '1100',
#                                       'day': 2,
#                                       'open': '0000'},
#                                      {'close': '2359',
#                                       'day': 2,
#                                       'open': '1300'},
#                                      {'close': '1200',
#                                       'day': 3,
#                                       'open': '0000'},
#                                      {'close': '2359',
#                                       'day': 3,
#                                       'open': '1300'},
#                                      {'close': '1200',
#                                       'day': 4,
#                                       'open': '0000'},
#                                      {'close': '2359',
#                                       'day': 4,
#                                       'open': '1300'},
#                                      {'close': '0100',
#                                       'day': 5,
#                                       'open': '0000'},
#                                      {'close': '2359',
#                                       'day': 5,
#                                       'open': '1300'},
#                                      {'close': '0100',
#                                       'day': 6,
#                                       'open': '0000'},
#                                      {'close': '2359',
#                                       'day': 6,
#                                       'open': '1300'},
#                                      {'close': '0100',
#                                       'day': 7,
#                                       'open': '0000'},
#                                      {'close': '2100',
#                                       'day': 7,
#                                       'open': '1400'}]},
#                'name': 'The Wings Tecnológico',
#                'popularity': 0.9702705268153773,
#                'price': 1,
#                'rating': 7.4,
#                'tips': [{'created_at': '2017-10-18T02:52:25.000Z',
#                          'text': 'La hamburguesa con alita.'},
#                         {'created_at': '2017-10-01T21:06:19.000Z',
#                          'text': 'Buenas alitas :)'},
#                         {'created_at': '2017-04-12T01:29:43.000Z',
#                          'text': 'Sabor, atención, buffet de alitas, todo de '
#                                  'lujo'},
#                         {'created_at': '2017-04-12T01:27:44.000Z',
#                          'text': 'Su buffet de alitas está de 10, la atención '
#                                  'súper rápida, sus salsas bien ricas, todo '
#                                  'excelente en este lugar, se los recomiendo '
#                                  'al 100, además no hay lista de espera eterna '
#                                  'como en otros buffets'},
#                         {'created_at': '2017-03-28T16:00:37.000Z',
#                          'text': 'El Buffete de alitas, Martes y Jueves y de '
#                                  'sabor Ajo Picante y Cajun.'}]},
#               {'distance': 298,
#                'hours': {'display': 'Mon-Sat 12:00-23:00; Sun 12:00-19:00',
#                          'is_local_holiday': False,
#                          'open_now': False,
#                          'regular': [{'close': '2300',
#                                       'day': 1,
#                                       'open': '1200'},
#                                      {'close': '2300',
#                                       'day': 2,
#                                       'open': '1200'},
#                                      {'close': '2300',
#                                       'day': 3,
#                                       'open': '1200'},
#                                      {'close': '2300',
#                                       'day': 4,
#                                       'open': '1200'},
#                                      {'close': '2300',
#                                       'day': 5,
#                                       'open': '1200'},
#                                      {'close': '2300',
#                                       'day': 6,
#                                       'open': '1200'},
#                                      {'close': '1900',
#                                       'day': 7,
#                                       'open': '1200'}]},
#                'name': 'El Buen Taco de Cecina',
#                'popularity': 0.968827717133365,
#                'price': 2,
#                'rating': 8.1,
#                'tips': [{'created_at': '2019-10-02T02:00:38.000Z',
#                          'text': 'La verdad sí están caros, pero la cecina '
#                                  'tiene muy buen sabor. Pidan un queso carne, '
#                                  'valen la pena. Ahhh y venden cerveza!!'},
#                         {'created_at': '2019-08-16T19:45:33.000Z',
#                          'text': 'Excelentes tacos, los amo!'},
#                         {'created_at': '2019-05-03T04:16:04.000Z',
#                          'text': 'Buena torta de cecina y longaniza está con '
#                                  'madre'},
#                         {'created_at': '2019-01-28T16:08:02.000Z',
#                          'text': 'La verdad están caros para lo que son. El '
#                                  'chorizo está muy muy grasoso'},
#                         {'created_at': '2018-08-16T01:43:18.000Z',
#                          'text': 'Me dieron caro taco con raquítismo....y no '
#                                  'pedí nada más porque me sentí estafada... '
#                                  'Jajaja'}]},
#               {'distance': 388,
#                'hours': {'display': 'Mon-Thu 13:30-23:00; Fri 13:30-23:59; Sat '
#                                     '00:00-12:00, 13:30-23:59; Sun '
#                                     '00:00-12:00, 13:30-18:00',
#                          'is_local_holiday': False,
#                          'open_now': False,
#                          'regular': [{'close': '2300',
#                                       'day': 1,
#                                       'open': '1330'},
#                                      {'close': '2300',
#                                       'day': 2,
#                                       'open': '1330'},
#                                      {'close': '2300',
#                                       'day': 3,
#                                       'open': '1330'},
#                                      {'close': '2300',
#                                       'day': 4,
#                                       'open': '1330'},
#                                      {'close': '2359',
#                                       'day': 5,
#                                       'open': '1330'},
#                                      {'close': '1200',
#                                       'day': 6,
#                                       'open': '0000'},
#                                      {'close': '2359',
#                                       'day': 6,
#                                       'open': '1330'},
#                                      {'close': '1200',
#                                       'day': 7,
#                                       'open': '0000'},
#                                      {'close': '1800',
#                                       'day': 7,
#                                       'open': '1330'}]},
#                'name': 'Argentilia',
#                'popularity': 0.9833507356430945,
#                'price': 2,
#                'rating': 8.5,
#                'tips': [{'created_at': '2023-02-11T16:48:35.000Z',
#                          'text': 'Los cortes de carne son buenos en general.'},
#                         {'created_at': '2022-11-17T03:55:35.000Z',
#                          'text': 'El servicio es bueno, el restaurante está en '
#                                  'muy buenas condiciones, las porciones son '
#                                  'pequeñas, muy bueno el pollo a la parrilla y '
#                                  'las empanadas'},
#                         {'created_at': '2021-12-07T18:26:52.000Z',
#                          'text': 'La comida rica, el servicio pésimo'},
#                         {'created_at': '2021-12-05T00:38:26.000Z',
#                          'text': 'El personal es extremadamente amable, la '
#                                  'carne de repente falta sabor, pide término '
#                                  '3/4 la traen 1/2 y en la plancha se acaba de '
#                                  'cocer'},
#                         {'created_at': '2019-11-06T03:54:15.000Z',
#                          'text': 'Los tacos de camarón muy buenos'}]},
#               {'distance': 435,
#                'hours': {'display': 'Mon 13:00-23:59; Tue-Sun 00:00-2:00',
#                          'is_local_holiday': False,
#                          'open_now': False,
#                          'regular': [{'close': '2359',
#                                       'day': 1,
#                                       'open': '1300'},
#                                      {'close': '0200',
#                                       'day': 2,
#                                       'open': '0000'},
#                                      {'close': '2359',
#                                       'day': 2,
#                                       'open': '1300'},
#                                      {'close': '0200',
#                                       'day': 3,
#                                       'open': '0000'},
#                                      {'close': '2359',
#                                       'day': 3,
#                                       'open': '1300'},
#                                      {'close': '0200',
#                                       'day': 4,
#                                       'open': '0000'},
#                                      {'close': '2359',
#                                       'day': 4,
#                                       'open': '1300'},
#                                      {'close': '0200',
#                                       'day': 5,
#                                       'open': '0000'},
#                                      {'close': '2359',
#                                       'day': 5,
#                                       'open': '1300'},
#                                      {'close': '0200',
#                                       'day': 6,
#                                       'open': '0000'},
#                                      {'close': '2359',
#                                       'day': 6,
#                                       'open': '1300'},
#                                      {'close': '0200',
#                                       'day': 7,
#                                       'open': '0000'},
#                                      {'close': '1800',
#                                       'day': 7,
#                                       'open': '1300'}]},
#                'name': 'El Caserio',
#                'popularity': 0.9755861414333176,
#                'rating': 8.5,
#                'tips': [{'created_at': '2022-02-15T22:37:19.000Z',
#                          'text': 'Carpaccio de Res, fabada, paella mixta y el '
#                                  'postre de manzana hojaldrada con helado de '
#                                  'vainilla, hasta el café americano es muy '
#                                  'bueno'},
#                         {'created_at': '2021-08-09T20:49:42.000Z',
#                          'text': 'Filete riojano delicioso y el lechón plato '
#                                  'estrella , el servicio espectacular y los '
#                                  'precios muyyy  accesibles'},
#                         {'created_at': '2020-08-07T22:51:02.000Z',
#                          'text': 'Los chiles en nogada son deliciosos'},
#                         {'created_at': '2019-05-25T23:10:16.000Z',
#                          'text': 'Todo delicioso peeeeeo permiten fumar puro y '
#                                  'cigarros aún con niños en las mesas, ellos y '
#                                  'nosotros. No podía con las náuseas por el '
#                                  'olor de la mesa de a lado'},
#                         {'created_at': '2019-04-21T19:46:16.000Z',
#                          'text': 'Carpaccio de res y el lechón son '
#                                  'imperdonables'}]},
#               {'distance': 445,
#                'hours': {'is_local_holiday': False, 'open_now': False},
#                'name': 'La Trattoria de la Piccola Giovanna',
#                'popularity': 0.9742192691029901,
#                'price': 1,
#                'rating': 8.4,
#                'tips': [{'created_at': '2022-06-15T18:54:48.000Z',
#                          'text': 'Huevos rancheros!!'},
#                         {'created_at': '2021-05-21T17:46:10.000Z',
#                          'text': 'Asadura is great'},
#                         {'created_at': '2020-10-26T17:22:02.000Z',
#                          'text': 'Buen lugar para almorzar'},
#                         {'created_at': '2019-12-07T16:43:21.000Z',
#                          'text': 'El chambarete, el café , asadura, en general '
#                                  'esta muy buena la comida'},
#                         {'created_at': '2019-08-23T21:56:11.000Z',
#                          'text': 'Muy buenos los huevos revueltos con '
#                                  'chicharrón'}]},
#               {'distance': 492,
#                'hours': {'is_local_holiday': False, 'open_now': False},
#                'name': 'Toks',
#                'popularity': 0.9904888467014713,
#                'price': 2,
#                'rating': 8.1,
#                'tips': [{'created_at': '2020-09-12T18:46:14.000Z',
#                          'text': 'El de la entrada .. prepotente ..!!!'},
#                         {'created_at': '2020-09-12T18:44:55.000Z',
#                          'text': 'El tipo de la entrada es prepotente , nunca '
#                                  'está en su lugar y cuando te pasas a buscar '
#                                  'lugar quiere que te regreses para tomarte la '
#                                  'temperatura , y estoy de acuerdo ,  pero con '
#                                  'respeto al cliente'},
#                         {'created_at': '2020-02-26T04:52:35.000Z',
#                          'text': 'Los desayunos...'},
#                         {'created_at': '2020-02-26T04:51:42.000Z',
#                          'text': 'Las cadenas de restaurantes a sus clientes '
#                                  'frecuentes les otorgan Tarjetas de '
#                                  'lealtad.... (vips, portón ..etc),  aquí te '
#                                  'dicen que ellos las manejan pero es mentira, '
#                                  'tienen mucho tiempo que no dan una'},
#                         {'created_at': '2020-02-26T04:23:35.000Z',
#                          'text': 'Los desayunos'}]},
#               {'distance': 608,
#                'hours': {'is_local_holiday': False, 'open_now': False},
#                'name': 'La Esperanza',
#                'popularity': 0.9952349311817751,
#                'price': 2,
#                'rating': 9.0,
#                'tips': [{'created_at': '2019-09-22T02:56:24.000Z',
#                          'text': 'Todo lo que ahí se expende para consumo es '
#                                  'excelente.'},
#                         {'created_at': '2018-10-08T02:56:54.000Z',
#                          'text': 'El pan es muy rico, hay mucha variedad y es '
#                                  'de calidad'},
#                         {'created_at': '2018-05-10T18:16:49.000Z',
#                          'text': 'Realmente un pan muy rico(aunque tampoco '
#                                  'barato),pero vale la pena.'},
#                         {'created_at': '2018-03-01T01:50:45.000Z',
#                          'text': 'Todo muy graso, y no tan rico'},
#                         {'created_at': '2017-10-30T00:12:41.000Z',
#                          'text': 'Delicioso todo. Hasta los jugos de '
#                                  'naranja!.'}]},
#               {'distance': 581,
#                'hours': {'display': 'Mon-Thu 13:00-23:00; Fri-Sat 13:00-24:00; '
#                                     'Sun 13:00-22:00',
#                          'is_local_holiday': False,
#                          'open_now': True,
#                          'regular': [{'close': '2300',
#                                       'day': 1,
#                                       'open': '1300'},
#                                      {'close': '2300',
#                                       'day': 2,
#                                       'open': '1300'},
#                                      {'close': '2300',
#                                       'day': 3,
#                                       'open': '1300'},
#                                      {'close': '2300',
#                                       'day': 4,
#                                       'open': '1300'},
#                                      {'close': '+0000',
#                                       'day': 5,
#                                       'open': '1300'},
#                                      {'close': '+0000',
#                                       'day': 6,
#                                       'open': '1300'},
#                                      {'close': '2200',
#                                       'day': 7,
#                                       'open': '1300'}]},
#                'name': 'Sushi Roll',
#                'popularity': 0.9878120550545799,
#                'price': 2,
#                'rating': 8.2,
#                'tips': [{'created_at': '2019-05-08T19:11:35.000Z',
#                          'text': 'La comida y el lugar están bien sin embargo '
#                                  'no hay wi fi pésimo.'},
#                         {'created_at': '2019-03-30T21:54:55.000Z',
#                          'text': 'Es lento lento lento el servicio'},
#                         {'created_at': '2018-12-13T03:30:49.000Z',
#                          'text': 'En noches de sushi lleguen temprano porque '
#                                  'la espera es muuuuucha'},
#                         {'created_at': '2018-12-03T01:18:56.000Z',
#                          'text': 'La Victoria en michelada Cubana es la '
#                                  'mejor!! 🍺👌🏻'},
#                         {'created_at': '2018-07-22T19:54:03.000Z',
#                          'text': 'Rockefeller roll, riquísimo!!'}]}]},
#  {'context': {'geo_bounds': {'circle': {'center': {'latitude': 20.59,
#                                                    'longitude': -100.4},
#                                         'radius': 1000}}},
#   'results': [{'distance': 173,
#                'hours': {'display': 'Open Daily 9:00-17:00',
#                          'is_local_holiday': False,
#                          'open_now': False,
#                          'regular': [{'close': '1700',
#                                       'day': 1,
#                                       'open': '0900'},
#                                      {'close': '1700',
#                                       'day': 2,
#                                       'open': '0900'},
#                                      {'close': '1700',
#                                       'day': 3,
#                                       'open': '0900'},
#                                      {'close': '1700',
#                                       'day': 4,
#                                       'open': '0900'},
#                                      {'close': '1700',
#                                       'day': 5,
#                                       'open': '0900'},
#                                      {'close': '1700',
#                                       'day': 6,
# ...
#                         {'created_at': '2015-09-22T15:32:36.000Z',
#                          'text': 'Tostada macara y CHIMICHANGAS, panque de '
#                                  'plátano y coulant de chocolate'},
#                         {'created_at': '2015-06-26T18:06:42.000Z',
#                          'text': 'Pide los combos, son especiales y baratos'},
#                         {'created_at': '2014-08-24T20:56:24.000Z',
#                          'text': 'Tostada Macara inigualable por sabor y '
#                                  'presentación, súper recomendable'}]},
#               {'distance': 322,
#                'hours': {'display': 'Open Daily 8:00-22:30',
#                          'is_local_holiday': False,
#                          'open_now': True,
#                          'regular': [{'close': '2230',
#                                       'day': 1,
#                                       'open': '0800'},
#                                      {'close': '2230',
#                                       'day': 2,
#                                       'open': '0800'},
#                                      {'close': '2230',
#                                       'day': 3,
#                                       'open': '0800'},
#                                      {'close': '2230',
#                                       'day': 4,
#                                       'open': '0800'},
#                                      {'close': '2230',
#                                       'day': 5,
#                                       'open': '0800'},
#                                      {'close': '2230',
#                                       'day': 6,
#                                       'open': '0800'},
#                                      {'close': '2230',
#                                       'day': 7,
#                                       'open': '0800'}]},
#                'name': 'Mara & Co',
#                'popularity': 0.9905268153773137,
#                'rating': 7.8,
#                'tips': [{'created_at': '2020-04-05T00:44:04.000Z',
#                          'text': 'Execelente lugar para chelear. Cerveza '
#                                  'artesanal a buen precio.'},
#                         {'created_at': '2018-12-14T19:14:07.000Z',
#                          'text': 'La comida esta bien, además la selección (y '
#                                  'costo) de cervezas artesanales es muy buena '
#                                  '(salva cerveza Toro que es una porquería, '
#                                  'pero eso no es culpa de Mara&Co)'},
#                         {'created_at': '2018-04-11T00:51:37.000Z',
#                          'text': 'Cerveza muy buena y a excelente precio'},
#                         {'created_at': '2017-11-12T13:54:21.000Z',
#                          'text': 'Tienen una amplia variedad de cervezas '
#                                  'artesanales y el lugar está a gusto para '
#                                  'pasar el rato tranquilo, ya sea como comida '
#                                  'familiar, pa ver el fut y precopear. Digno '
#                                  'lugar para conocer y regresar!!'},
#                         {'created_at': '2017-09-22T19:52:59.000Z',
#                          'text': 'Lugar con buena decoración, acogedor. '
#                                  'Precios accesibles y promociones los martes. '
#                                  'Pidan el sándwich de manzana, muy bueno'}]},
#               {'distance': 340,
#                'hours': {'display': 'Mon-Sat 13:00-20:00; Sun 13:00-19:00',
#                          'is_local_holiday': False,
#                          'open_now': False,
#                          'regular': [{'close': '2000',
#                                       'day': 1,
#                                       'open': '1300'},
#                                      {'close': '2000',
#                                       'day': 2,
#                                       'open': '1300'},
#                                      {'close': '2000',
#                                       'day': 3,
#                                       'open': '1300'},
#                                      {'close': '2000',
#                                       'day': 4,
#                                       'open': '1300'},
#                                      {'close': '2000',
#                                       'day': 5,
#                                       'open': '1300'},
#                                      {'close': '2000',
#                                       'day': 6,
#                                       'open': '1300'},
#                                      {'close': '1900',
#                                       'day': 7,
#                                       'open': '1300'}]},
#                'name': 'Vivar Sushi',
#                'popularity': 0.12022781205505458,
#                'price': 2,
#                'rating': 8.0,
#                'tips': [{'created_at': '2021-06-20T22:01:55.000Z',
#                          'text': 'Los refrescos de la Coca-Cola, ya sería el '
#                                  'colmo que no.'},
#                         {'created_at': '2019-03-22T01:30:23.000Z',
#                          'text': 'Petfriendly!!!! 😍🐾 y la bomba es una '
#                                  'delicia!'},
#                         {'created_at': '2019-02-28T21:44:00.000Z',
#                          'text': '¡Excelente lugar,calidad y servicio! Precios '
#                                  'accesibles y delicioso sabor.'},
#                         {'created_at': '2019-02-15T02:48:10.000Z',
#                          'text': 'Muy rico 😋'},
#                         {'created_at': '2018-12-23T02:52:06.000Z',
#                          'text': 'Súper rico'}]},
#               {'distance': 391,
#                'hours': {'is_local_holiday': False, 'open_now': False},
#                'name': 'Tacos la Capilla',
#                'popularity': 0.9868818224964404,
#                'price': 1,
#                'rating': 8.0,
#                'tips': [{'created_at': '2023-07-08T19:36:03.000Z',
#                          'text': 'Los licuados están deliciosos! Los tacos '
#                                  'están ricos pero mi favoritos son los de '
#                                  'picadillo 👌🏻'},
#                         {'created_at': '2019-05-01T17:11:05.000Z',
#                          'text': 'Mi lugar favorito siempre, plato de fruta '
#                                  'con yogurt y miel, el capuchino que es '
#                                  'buenísimo y un par de tacos de chicharrón '
#                                  'prensado.'},
#                         {'created_at': '2019-03-30T21:00:18.000Z',
#                          'text': 'buenos tacos....las salsas de primera y los '
#                                  'licuados una garantia....regreso por que '
#                                  'regreso'},
#                         {'created_at': '2019-02-02T16:41:38.000Z',
#                          'text': 'One of each one...'},
#                         {'created_at': '2018-10-21T20:46:16.000Z',
#                          'text': 'Los tacos de carne !!! Y los licuados el '
#                                  'complemento Perfecto !'}]},
#               {'distance': 701,
#                'hours': {'is_local_holiday': False, 'open_now': False},
#                'name': 'Los gusanos de chucho',
#                'popularity': 0.984280968201234,
#                'price': 1,
#                'rating': 8.6,
#                'tips': [{'created_at': '2021-07-25T18:35:00.000Z',
#                          'text': 'Buenas porciones y excelentes precios, buena '
#                                  'opción para comer algunos tacos. 🌮'},
#                         {'created_at': '2019-07-14T03:29:41.000Z',
#                          'text': 'Los tacos de suadero, el gusano de pastor '
#                                  'está muy regular le falta sabor y es más '
#                                  'tortilla que carne, cebolla y aguacate.'},
#                         {'created_at': '2018-06-22T01:57:25.000Z',
#                          'text': 'Muy buenos, y te atienden y sirven muy '
#                                  'rápido'},
#                         {'created_at': '2018-03-12T16:55:40.000Z',
#                          'text': 'Muy buenos y a buen precio'},
#                         {'created_at': '2018-01-27T17:59:07.000Z',
#                          'text': 'Gusano de pastor, que cosa tan hermosa '
#                                  'eres'}]},
#               {'distance': 732,
#                'hours': {'display': 'Tue-Wed 14:00-23:30; Thu 14:00-23:59; '
#                                     'Fri-Sun 00:00-2:30',
#                          'is_local_holiday': False,
#                          'open_now': True,
#                          'regular': [{'close': '2330',
#                                       'day': 2,
#                                       'open': '1400'},
#                                      {'close': '2330',
#                                       'day': 3,
#                                       'open': '1400'},
#                                      {'close': '2359',
#                                       'day': 4,
#                                       'open': '1400'},
#                                      {'close': '0230',
#                                       'day': 5,
#                                       'open': '0000'},
#                                      {'close': '2359',
#                                       'day': 5,
#                                       'open': '1400'},
#                                      {'close': '0230',
#                                       'day': 6,
#                                       'open': '0000'},
#                                      {'close': '2359',
#                                       'day': 6,
#                                       'open': '1400'},
#                                      {'close': '0230',
#                                       'day': 7,
#                                       'open': '0000'},
#                                      {'close': '2030',
#                                       'day': 7,
#                                       'open': '1400'}]},
#                'name': 'Baja 5 Gastrobar',
#                'popularity': 0.968391077361177,
#                'price': 3,
#                'rating': 8.0,
#                'tips': [{'created_at': '2019-11-30T23:43:44.000Z',
#                          'text': 'Tacos rebozado de camarón y aguachile '
#                                  'delicioso ! Muy recomendable ! Agustito en '
#                                  'la playa'},
#                         {'created_at': '2019-11-01T23:07:05.000Z',
#                          'text': 'Una mierda 1000 pesos por 3 adultos y 2 '
#                                  'cervezas. Sabor equis en la comida. Meseros '
#                                  'sordos'},
#                         {'created_at': '2019-04-10T20:09:36.000Z',
#                          'text': 'No me gusto nada de lo consumí, las papas '
#                                  'sin sabor, las bebidas igual'},
#                         {'created_at': '2018-10-07T05:42:58.000Z',
#                          'text': 'La cerveza porque no hay que prepararla, la '
#                                  'comida esta mala'},
#                         {'created_at': '2018-04-08T01:05:31.000Z',
#                          'text': 'La enseñada cesar y las micheladas son muy '
#                                  'buenas'}]},
#               {'distance': 710,
#                'hours': {'display': 'Tue-Sat 13:00-23:59; Sun 13:00-20:00',
#                          'is_local_holiday': False,
#                          'open_now': True,
#                          'regular': [{'close': '2359',
#                                       'day': 2,
#                                       'open': '1300'},
#                                      {'close': '2359',
#                                       'day': 3,
#                                       'open': '1300'},
#                                      {'close': '2359',
#                                       'day': 4,
#                                       'open': '1300'},
#                                      {'close': '2359',
#                                       'day': 5,
#                                       'open': '1300'},
#                                      {'close': '2359',
#                                       'day': 6,
#                                       'open': '1300'},
#                                      {'close': '2000',
#                                       'day': 7,
#                                       'open': '1300'}]},
#                'name': 'Estación Central QRO',
#                'popularity': 0.9843379212149976,
#                'rating': 7.7,
#                'tips': [{'created_at': '2019-07-22T01:33:39.000Z',
#                          'text': 'Pésimo no hay comida dicen que no tienen los '
#                                  'ingredientes o sea!! 🤦🏻\u200d♂️ mal mal'},
#                         {'created_at': '2019-03-30T21:01:56.000Z',
#                          'text': 'bueno el.servicio las guesas muy ricas...'},
#                         {'created_at': '2019-02-10T03:44:27.000Z',
#                          'text': 'Esta muy agradable el lugar, lo malo es la '
#                                  'desagradable música reggaetón que esta todo '
#                                  'el tiempo es desesperante.'},
#                         {'created_at': '2018-09-23T01:20:01.000Z',
#                          'text': 'El agua de horchata!?. Las alitas no son lo '
#                                  'mejor el pollo tiene un sabor extraño.'},
#                         {'created_at': '2018-06-30T20:20:43.000Z',
#                          'text': 'Las hamburguesas están ricas y la cerveza '
#                                  'artesanal. ...muy lento el servicio y muchas '
#                                  'moscas'}]},
#               {'distance': 750,
#                'hours': {'display': 'Mon-Fri 9:00-18:30',
#                          'is_local_holiday': False,
#                          'open_now': False,
#                          'regular': [{'close': '1830',
#                                       'day': 1,
#                                       'open': '0900'},
#                                      {'close': '1830',
#                                       'day': 2,
#                                       'open': '0900'},
#                                      {'close': '1830',
#                                       'day': 3,
#                                       'open': '0900'},
#                                      {'close': '1830',
#                                       'day': 4,
#                                       'open': '0900'},
#                                      {'close': '1830',
#                                       'day': 5,
#                                       'open': '0900'}]},
#                'name': 'Food Station',
#                'popularity': 0.9148172757475083,
#                'price': 1,
#                'rating': 7.9,
#                'tips': [{'created_at': '2019-03-22T03:31:41.000Z',
#                          'text': 'Todo está bueno'},
#                         {'created_at': '2017-01-16T17:06:32.000Z',
#                          'text': 'El gohan teriyaki es muy bueno pero no '
#                                  'recomiendo los chilaquiles 🙅'},
#                         {'created_at': '2016-11-04T16:09:03.000Z',
#                          'text': 'Todo está riquísimo, menos los chilaquiles!! '
#                                  'Excelente servicio'},
#                         {'created_at': '2016-04-12T15:20:26.000Z',
#                          'text': 'La especialidad de Food Sation son los '
#                                  "Gohan's!"},
#                         {'created_at': '2016-03-02T00:59:22.000Z',
#                          'text': 'Good food and service but they take too long '
#                                  'for coffee orders. Mind your time.'}]}]}]

# %% [markdown]
# ## 2. Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
#Create a list of restaurant tips for all restaurants around a bike station, in this example station in the position 1 in the list. 
all_tips_per_bike_station = [(r['name'], tip['text']) for r in saved_restaurants_list[1]['results'] for tip in r['tips']]
pprint(all_tips_per_bike_station)

# %%
#Create a list of restaurant hours for all restaurants around a bike station, in this example station in the position 4 in the list. 
all_hoursdisplay_per_bike_station = [(r['name'], hours['display']) 
                                     for r in saved_restaurants_list[4]['results'] 
                                     for hours in [r['hours']]
                                     if isinstance(r['hours'], dict) and 'display' in r['hours']
                                    ]
pprint(all_hoursdisplay_per_bike_station)
# Out:
# [('Tortas Quality', 'Mon-Fri 7:30-15:00; Sat 7:30-13:30'),
#  ('Cafe Tulipe', 'Mon-Thu 8:00-22:00; Fri 8:00-23:00; Sat-Sun 8:00-22:00'),
#  ('Norteño Grill Restaurante',
#   'Mon-Wed 13:00-22:00; Thu-Sat 13:00-23:59; Sun 13:00-18:00'),
#  ('Sonora Grill - Puerta Victoria',
#   'Mon 00:00-2:00; Tue-Thu 13:00-23:59; Fri-Sun 00:00-2:00'),
#  ('Mirthala', 'Mon-Sat 7:00-23:00; Sun 8:00-17:00')]

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
# Retrieve information of interest: name, distance, popularity, rating, price and hours (display):

extracted_data = []

for entry in saved_restaurants_list:
    for result in entry['results']:
        hours_display = result['hours'].get('display', None)  # Get the 'display' value if it exists, else None
        price = result.get('price', None) # Get the price if exists, otherwise None. 
        if hours_display is not None:
            extracted_data.append({
                'distance': result['distance'],
                'name': result['name'],
                'popularity': result['popularity'],
                'price': price,
                'rating': result['rating'],
                'hours_display': hours_display
            })

# Creating DataFrame
restaurant_info_df = pd.DataFrame(extracted_data)
restaurant_info_df
# Out:
#      distance                       name  popularity  price  rating  \
# 0          47   Monosabio Hamburguesería    0.979649    3.0     8.5
# 1         149           Taqueria Jalisco    0.937276    1.0     7.9
# 2         158                 Los Idolos    0.941187    1.0     7.7
# 3         243  Fogon do Brasil Queretaro    0.989483    2.0     8.2
# 4         598                 Sushi Roll    0.987812    2.0     8.2
# ..        ...                        ...         ...    ...     ...
# 236       322                  Mara & Co    0.990527    NaN     7.8
# 237       340                Vivar Sushi    0.120228    2.0     8.0
# 238       732           Baja 5 Gastrobar    0.968391    3.0     8.0
# 239       710       Estación Central QRO    0.984338    NaN     7.7
# 240       750               Food Station    0.914817    1.0     7.9
#
#                                          hours_display
# 0    Tue 13:00-22:00; Wed 13:00-22:30; Thu-Sat 13:0...
# 1                                 Open Daily 0:00-4:00
# 2                 Tue-Sat 12:30-22:00; Sun 12:30-20:00
# 3                 Mon-Sat 13:00-22:00; Sun 13:00-21:00
# 4    Mon-Thu 13:00-23:00; Fri-Sat 13:00-24:00; Sun ...
# ..                                                 ...
# 236                              Open Daily 8:00-22:30
# 237               Mon-Sat 13:00-20:00; Sun 13:00-19:00
# 238  Tue-Wed 14:00-23:30; Thu 14:00-23:59; Fri-Sun ...
# 239               Tue-Sat 13:00-23:59; Sun 13:00-20:00
# 240                                 Mon-Fri 9:00-18:30
#
# [241 rows x 6 columns]

# %% [markdown]
# *Analysis of code: The condition if hours_display is not None: is used to filter out entries where the 'display' key is missing from the 'hours' dictionary. If 'display' is missing, the get() method returns None, indicating that the opening hours display information is not available for that entry.*
#
# *By checking if hours_display is not None, the code ensures that only entries with the 'display' key present in the 'hours' dictionary are included in the extracted_data list. This way, the resulting DataFrame will only contain rows where the opening hours display information is available, and it avoids adding incomplete or missing data to the DataFrame.*

# %% [markdown]
# # YELP

# %% [markdown]
# ## 1. Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %% [markdown]
# *The personal Yelp API Key was set up in a different Jupyter file to use as a variable in this file.*

# %%
yelp_api_key = os.environ["YELP_API_KEY"]

# Defining a function to get the get request giving a coordinate from geocodes
def find_restaurants_yelp(latitude, longitude):
    url = "https://api.yelp.com/v3/businesses/search?term=restaurants&radius=1000&categories=&price=1&price=2&price=3&price=4&attributes=parking&attributes=wifi&attributes=ambience&sort_by=best_match&limit=20"
    headers = {"accept": "application/json",
               'Authorization':'Bearer ' + yelp_api_key}
    response = requests.get(url=url+f'&latitude={latitude}'+f'&longitude={longitude}', headers = headers) 
    data_yelp = response.json()
    return data_yelp

# Create an empty list to append the information obtained from the find_restaurants function for each of the geocode pairs from geocodes. 
restaurants_list_yelp = []

for latitude, longitude in stations_coor_list: 
    data_yelp = find_restaurants_yelp(latitude, longitude)
    restaurants_list_yelp.append(data_yelp)

# %%
# Saving and loading information into files with JSON

with open('data3.json', 'w') as f:
    json.dump(restaurants_list_yelp, f)

with open('data3.json', 'r') as f:
    saved_restaurants_list_yelp = json.loads(f.read())

pprint(saved_restaurants_list_yelp)
# Out:
# [{'businesses': [{'alias': 'fogon-do-brasil-santiago-de-querétaro-2',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'brazilian', 'title': 'Brazilian'}],
#                   'coordinates': {'latitude': 20.5804272,
#                                   'longitude': -100.4117841},
#                   'display_phone': '+52 442 218 3537',
#                   'distance': 270.08098203444536,
#                   'id': 'N5phZxUHfVIYEZlS9lkOsA',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-Y-XyEqDfGl42750mRdoMw/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Prol. Av. Zaragoza 60',
#                                'address2': 'Col. Ensueño',
#                                'address3': None,
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Prol. Av. Zaragoza 60',
#                                                    'Col. Ensueño',
#                                                    '76178 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76178'},
#                   'name': 'Fogon do Brasil',
#                   'phone': '+524422183537',
#                   'price': '$$',
#                   'rating': 3.0,
#                   'review_count': 1,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/fogon-do-brasil-santiago-de-quer%C3%A9taro-2?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'josecho-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': '',
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#                                  {'alias': 'international',
#                                   'title': 'International'}],
#                   'coordinates': {'latitude': 20.573349,
#                                   'longitude': -100.40571},
#                   'display_phone': '+52 442 216 0201',
#                   'distance': 919.1377255821862,
#                   'id': 'cEerjCeV1EHqfxCGQHkoxA',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/V5XJuiouEd19HPbnMEUPLA/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Dalia 1',
#                                'address2': 'Col. Orquídeas',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Dalia 1',
#                                                    'Col. Orquídeas',
#                                                    '76180 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76180'},
#                   'name': 'Josecho',
#                   'phone': '+524422160201',
#                   'price': '$$$$',
#                   'rating': 5.0,
#                   'review_count': 1,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/josecho-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'karnes-en-su-jugo-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'comfortfood',
#                                   'title': 'Comfort Food'}],
#                   'coordinates': {'latitude': 20.573085,
#                                   'longitude': -100.415071},
#                   'display_phone': '+52 442 215 3468',
#                   'distance': 1001.4996274292365,
#                   'id': 'louMKmmHCeVYM2sD5ZZu3A',
#                   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RY7I4ThEjV8kIEv_W0TF4w/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Ignacio Zaragoza 401',
#                                'address2': None,
#                                'address3': None,
#                                'city': 'Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Ignacio Zaragoza 401',
#                                                    '76180 Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76180'},
#                   'name': 'Karnes en Su Jugo',
#                   'phone': '+524422153468',
#                   'price': '$$',
#                   'rating': 4.8,
#                   'review_count': 4,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/karnes-en-su-jugo-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'ichiban-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#                   'coordinates': {'latitude': 20.5722438362504,
#                                   'longitude': -100.406728799039},
#                   'display_phone': '+52 442 216 9319',
#                   'distance': 989.5846912507262,
#                   'id': 'cN6zUyJXp4yRKqQZgTmU0A',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dQUKpY5muXGh6VT8bklglA/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Av. Constituyentes 124',
#                                'address2': 'Col. Las Torres',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Av. Constituyentes 124',
#                                                    'Col. Las Torres',
#                                                    '76000 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76000'},
#                   'name': 'Ichiban',
#                   'phone': '+524422169319',
#                   'price': '$$',
#                   'rating': 3.8,
#                   'review_count': 8,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/ichiban-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'pawa-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': 'http://pawasushi.mx/menu/',
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                  {'alias': 'asianfusion',
#                                   'title': 'Asian Fusion'}],
#                   'coordinates': {'latitude': 20.5753384281775,
#                                   'longitude': -100.407446951017},
#                   'display_phone': '+52 442 193 5653',
#                   'distance': 641.4122809237988,
#                   'id': 'DNUclABh2R6GlEDWLsw7sg',
#                   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-2xIPDoMAL58RNo9JXCPZA/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Carretera Cuota a Celaya 5501',
#                                'address2': 'Col. La Granja',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Carretera Cuota a Celaya '
#                                                    '5501',
#                                                    'Col. La Granja',
#                                                    '76180 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76180'},
#                   'name': 'Pawa',
#                   'phone': '+524421935653',
#                   'price': '$$',
#                   'rating': 0.0,
#                   'review_count': 0,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/pawa-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'pizzeria-la-tómbola-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#                   'coordinates': {'latitude': 20.5726713605148,
#                                   'longitude': -100.405738461565},
#                   'display_phone': '+52 442 216 3386',
#                   'distance': 985.0333864317723,
#                   'id': 'JUuc2IWBJpYTLjkKkdlFuA',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FIenon2S8H7ON8N4nDiJcg/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Brasil 21',
#                                'address2': 'Col. Lomas de Querétaro',
#                                'address3': None,
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Brasil 21',
#                                                    'Col. Lomas de Querétaro',
#                                                    '76147 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76147'},
#                   'name': 'Pizzeria La Tómbola',
#                   'phone': '+524422163386',
#                   'price': '$$',
#                   'rating': 3.8,
#                   'review_count': 4,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/pizzeria-la-t%C3%B3mbola-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'las-delicias-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                   'coordinates': {'latitude': 20.5883440412493,
#                                   'longitude': -100.400578214679},
#                   'display_phone': '',
#                   'distance': 1289.7525451297515,
#                   'id': 'NG28oPaOx6b5WFkIMNdopg',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4I71k_9OAo6W5r7vu_7MGg/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Jose Ma. Pino Suarez 146',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Jose Ma. Pino Suarez 146',
#                                                    '76000 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76000'},
#                   'name': 'Las Delicias',
#                   'phone': '',
#                   'price': '$$',
#                   'rating': 5.0,
#                   'review_count': 1,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/las-delicias-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'el-fogón-del-pastor-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                   'coordinates': {'latitude': 20.5716912741975,
#                                   'longitude': -100.415146435989},
#                   'display_phone': '',
#                   'distance': 1138.5719433369422,
#                   'id': 'RXcWFb0Jrr0m8m2kYn49Pw',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MoriVrzS_-ZVjjXMkHyeSQ/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Av. Prolongación Zaragoza 799',
#                                'address2': 'Col. Mansiones del Valle',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Av. Prolongación Zaragoza '
#                                                    '799',
#                                                    'Col. Mansiones del Valle',
#                                                    'Santiago de Querétaro, '
#                                                    'Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': ''},
#                   'name': 'El Fogón del Pastor',
#                   'phone': '',
#                   'price': '$',
#                   'rating': 3.2,
#                   'review_count': 6,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/el-fog%C3%B3n-del-pastor-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'biergarten-eder-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'german', 'title': 'German'},
#                                  {'alias': 'beergardens',
#                                   'title': 'Beer Gardens'}],
#                   'coordinates': {'latitude': 20.5855481349866,
#                                   'longitude': -100.404300838709},
#                   'display_phone': '+52 442 215 1945',
#                   'distance': 793.9256855261241,
#                   'id': '0sw2Gd0wiYv9g_yTF3HZZQ',
#                   'image_url': '',
#                   'is_closed': False,
#                   'location': {'address1': 'José María Arteaga 221',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['José María Arteaga 221',
#                                                    '76010 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76010'},
#                   'name': 'Biergarten Eder',
#                   'phone': '+524422151945',
#                   'price': '$$',
#                   'rating': 0.0,
#                   'review_count': 0,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/biergarten-eder-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'cafe-amadeus-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'german', 'title': 'German'}],
#                   'coordinates': {'latitude': 20.5732231198711,
#                                   'longitude': -100.415522722415},
#                   'display_phone': '+52 442 216 9890',
#                   'distance': 1015.2471582199248,
#                   'id': 'nGpNSoh_ZdfdoOeWxmUkCA',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/09ae6wJu_4cjGtE5lACJ9w/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Prol. Zaragoza 306',
#                                'address2': 'Col. Jardines de la Hacienda',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Prol. Zaragoza 306',
#                                                    'Col. Jardines de la '
#                                                    'Hacienda',
#                                                    '76180 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76180'},
#                   'name': 'Cafe Amadeus',
#                   'phone': '+524422169890',
#                   'price': '$$',
#                   'rating': 3.7,
#                   'review_count': 3,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/cafe-amadeus-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'italiannis-los-virreyes',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': 'http://italiannis.com.mx/nuestro-menu/',
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'italian', 'title': 'Italian'},
#                                  {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#                   'coordinates': {'latitude': 20.57739986509,
#                                   'longitude': -100.405299730021},
#                   'display_phone': '+52 442 215 9438',
#                   'distance': 595.8029353643742,
#                   'id': 'rRLBKnUUpB1sIkuYHkRnbQ',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yqjJFjtiRqJy4Dwd6z9RGA/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Central Comercial Galerías '
#                                            'Querétaro',
#                                'address2': 'Av. 5 de Febrero 99',
#                                'address3': 'Col. los Virreyes',
#                                'city': 'Los Virreyes',
#                                'country': 'MX',
#                                'display_address': ['Central Comercial Galerías '
#                                                    'Querétaro',
#                                                    'Av. 5 de Febrero 99',
#                                                    'Col. los Virreyes',
#                                                    '76175 Los Virreyes, '
#                                                    'Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76175'},
#                   'name': "Italianni's",
#                   'phone': '+524422159438',
#                   'price': '$$',
#                   'rating': 2.5,
#                   'review_count': 2,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/italiannis-los-virreyes?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'sirloin-stockade-el-jacal',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': '',
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'buffets', 'title': 'Buffets'}],
#                   'coordinates': {'latitude': 20.575196425088,
#                                   'longitude': -100.409074931513},
#                   'display_phone': '+52 442 215 7407',
#                   'distance': 611.753314385608,
#                   'id': 'MMI6CiAAUBqbtzYuGhaLfg',
#                   'image_url': '',
#                   'is_closed': False,
#                   'location': {'address1': 'Autopista Celaya-Queretaro',
#                                'address2': 'Col. El Jacal',
#                                'address3': '',
#                                'city': 'El Jacal',
#                                'country': 'MX',
#                                'display_address': ['Autopista Celaya-Queretaro',
#                                                    'Col. El Jacal',
#                                                    '52140 El Jacal, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '52140'},
#                   'name': 'Sirloin Stockade',
#                   'phone': '+524422157407',
#                   'price': '$$',
#                   'rating': 2.0,
#                   'review_count': 1,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/sirloin-stockade-el-jacal?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'chilis-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': 'http://www.chilis.com.mx/menu/',
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'tradamerican', 'title': 'American'},
#                                  {'alias': 'tex-mex', 'title': 'Tex-Mex'}],
#                   'coordinates': {'latitude': 20.5776580217035,
#                                   'longitude': -100.405123734465},
#                   'display_phone': '+52 442 220 8626',
#                   'distance': 593.926455191836,
#                   'id': 'H0cm3AZDHrkj0a-CgX7jMA',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6H2HYqpyXVNdxSlns4xcAw/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Galerías Querétaro',
#                                'address2': 'Av. 5 de Febrero 99',
#                                'address3': 'Col. Álamos 3ra. Sección',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Galerías Querétaro',
#                                                    'Av. 5 de Febrero 99',
#                                                    'Col. Álamos 3ra. Sección',
#                                                    '76170 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76170'},
#                   'name': "Chili's",
#                   'phone': '+524422208626',
#                   'price': '$$',
#                   'rating': 3.0,
#                   'review_count': 1,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/chilis-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'de-cortés-a-bravo-santa-maría-magdalena',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': 'http://decortesabravo.com/nuestra-carta',
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#                                  {'alias': 'seafood', 'title': 'Seafood'}],
#                   'coordinates': {'latitude': 20.5721384702307,
#                                   'longitude': -100.405759625137},
#                   'display_phone': '+52 442 215 4891',
#                   'distance': 1037.8154184165255,
#                   'id': '8WeS9cjRxV0gWpjKd6JdCw',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Xdhxl3Z2eGG5HOuzYCXPXQ/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Brasil 27',
#                                'address2': 'Col. Lonas de Querétaro',
#                                'address3': '',
#                                'city': 'Santa María Magdalena',
#                                'country': 'MX',
#                                'display_address': ['Brasil 27',
#                                                    'Col. Lonas de Querétaro',
#                                                    '76200 Santa María '
#                                                    'Magdalena, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76200'},
#                   'name': 'De Cortés a Bravo',
#                   'phone': '+524422154891',
#                   'price': '$$',
#                   'rating': 0.0,
#                   'review_count': 0,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/de-cort%C3%A9s-a-bravo-santa-mar%C3%ADa-magdalena?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'don-carbón-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                   'coordinates': {'latitude': 20.5756521358563,
#                                   'longitude': -100.40723390834},
#                   'display_phone': '',
#                   'distance': 618.87746817876,
#                   'id': 'kt6T1PQZPp2Ae95UEqZQkA',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yq7MHXzXg_-JB_Rwf9ci6A/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Autopista Querétaro-Celaya 5501',
#                                'address2': 'Col. El Jacal',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Autopista Querétaro-Celaya '
#                                                    '5501',
#                                                    'Col. El Jacal',
#                                                    'Santiago de Querétaro, '
#                                                    'Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': ''},
#                   'name': 'Don Carbón',
#                   'phone': '',
#                   'price': '$',
#                   'rating': 3.0,
#                   'review_count': 2,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/don-carb%C3%B3n-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'sanborns-restaurant-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'bars', 'title': 'Bars'},
#                                  {'alias': 'mexican', 'title': 'Mexican'}],
#                   'coordinates': {'latitude': 20.5777602709885,
#                                   'longitude': -100.405586028751},
#                   'display_phone': '',
#                   'distance': 547.9726977437078,
#                   'id': 'EhAXz5dAdMmbeGdoCv8ECA',
#                   'image_url': '',
#                   'is_closed': False,
#                   'location': {'address1': 'Av. 5 de Febrero 99',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Av. 5 de Febrero 99',
#                                                    '76030 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76030'},
#                   'name': 'Sanborns Restaurant',
#                   'phone': '',
#                   'price': '$',
#                   'rating': 0.0,
#                   'review_count': 0,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/sanborns-restaurant-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'subway-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                  {'alias': 'salad', 'title': 'Salad'}],
#                   'coordinates': {'latitude': 20.584086928631,
#                                   'longitude': -100.401502515042},
#                   'display_phone': '+52 442 242 4063',
#                   'distance': 949.2752881812447,
#                   'id': '7sW2rNuqGCsZr1FhIsZFXw',
#                   'image_url': '',
#                   'is_closed': False,
#                   'location': {'address1': 'Av. Tecnológico 96',
#                                'address2': 'Col. Centro',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Av. Tecnológico 96',
#                                                    'Col. Centro',
#                                                    '76000 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76000'},
#                   'name': 'Subway',
#                   'phone': '+524422424063',
#                   'price': '$',
#                   'rating': 1.5,
#                   'review_count': 2,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/subway-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'the-italian-coffee-company-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'cafeteria', 'title': 'Cafeteria'}],
#                   'coordinates': {'latitude': 20.58848,
#                                   'longitude': -100.4032593},
#                   'display_phone': '',
#                   'distance': 1139.5093364125976,
#                   'id': '6va80UTv2VfNXwlqRBGcIA',
#                   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ppW9342IwoDnRPLaw218cA/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Calle Francisco I. Madero 10',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Calle Francisco I. Madero '
#                                                    '10',
#                                                    '76000 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76000'},
#                   'name': 'The Italian Coffee Company',
#                   'phone': '',
#                   'price': '$$',
#                   'rating': 0.0,
#                   'review_count': 0,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/the-italian-coffee-company-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'}],
#   'region': {'center': {'latitude': 20.58065, 'longitude': -100.40985}},
#   'total': 18},
#  {'businesses': [{'alias': 'tikua-sureste-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': 'http://tikua.mx/menu.php',
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'oaxacan', 'title': 'Oaxacan'},
#                                  {'alias': 'yucatan', 'title': 'Yucatan'}],
#                   'coordinates': {'latitude': 20.5934693,
#                                   'longitude': -100.3945344},
#                   'display_phone': '+52 442 403 4677',
#                   'distance': 1169.5500257882732,
#                   'id': 'Y2Iqqe13-n7_60q9ND0vMA',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EPQjzmlcf6bjSsFo3paTXg/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Ignacio Allende Sur 13',
#                                'address2': 'Col. Centro',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Ignacio Allende Sur 13',
#                                                    'Col. Centro',
#                                                    '76000 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76000'},
#                   'name': 'Tikua Sureste',
#                   'phone': '+524424034677',
#                   'price': '$$',
#                   'rating': 4.7,
#                   'review_count': 84,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/tikua-sureste-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'las-monjas-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                   'coordinates': {'latitude': 20.591753,
#                                   'longitude': -100.397906},
#                   'display_phone': '+52 442 212 1538',
#                   'distance': 890.7502818482272,
#                   'id': 'tJ6l8ffFPIV8nC1Lu1_3ew',
#                   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9m6Gar2-5yOi4_Nh1WBzAg/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Calle Ezequiel Montes 22',
#                                'address2': 'Col. Centro',
#                                'address3': None,
#                                'city': 'Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Calle Ezequiel Montes 22',
#                                                    'Col. Centro',
#                                                    '76000 Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76000'},
#                   'name': 'Las Monjas',
#                   'phone': '+524422121538',
#                   'price': '$$',
#                   'rating': 4.3,
#                   'review_count': 10,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/las-monjas-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'la-charamusca-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'cafeteria', 'title': 'Cafeteria'},
#                                  {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                   'coordinates': {'latitude': 20.5937056846876,
#                                   'longitude': -100.392927931273},
#                   'display_phone': '+52 442 962 0756',
#                   'distance': 1383.8435327527775,
#                   'id': 'q0Cy6GGB5iK4Im9ZJXm71Q',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/G_VPoAje9ROkMiKkzxiiRA/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Calle Benito Juarez Nte. 41',
#                                'address2': 'Col. Centro',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Calle Benito Juarez Nte. '
#                                                    '41',
#                                                    'Col. Centro',
#                                                    '76000 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76000'},
#                   'name': 'La Charamusca',
#                   'phone': '+524429620756',
#                   'price': '$',
#                   'rating': 4.8,
#                   'review_count': 6,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/la-charamusca-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'comedor-de-la-marquesa-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#                                  {'alias': 'breakfast_brunch',
#                                   'title': 'Breakfast & Brunch'}],
#                   'coordinates': {'latitude': 20.5918939934264,
#                                   'longitude': -100.393478098029},
#                   'display_phone': '',
#                   'distance': 1204.8725443722758,
#                   'id': 'ivehe-VOEolNPXrpAM0w7A',
#                   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lUiSxPqRSKC81ma10p3ckQ/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Calle Franciso I. Madero 41',
#                                'address2': 'Centro Histórico, 76000',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Calle Franciso I. Madero '
#                                                    '41',
#                                                    'Centro Histórico, 76000',
#                                                    'Santiago de Querétaro, '
#                                                    'Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': ''},
#                   'name': 'Comedor De La Marquesa',
#                   'phone': '',
#                   'price': '$$',
#                   'rating': 4.1,
#                   'review_count': 12,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/comedor-de-la-marquesa-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'portal-de-santa-rosa-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                   'coordinates': {'latitude': 20.5887012219347,
#                                   'longitude': -100.39647012949},
#                   'display_phone': '+52 442 214 9131',
#                   'distance': 740.8824320650791,
#                   'id': 'B6j6v1cLI9sE5Y6rsXA-1Q',
#                   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Tx89EkTT1WBvldt9RSF3gg/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Plaza Mariano de Las Casas',
#                                'address2': 'Mariano de Las Casas 17',
#                                'address3': 'Col. Centro',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Plaza Mariano de Las Casas',
#                                                    'Mariano de Las Casas 17',
#                                                    'Col. Centro',
#                                                    '76000 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76000'},
#                   'name': 'Portal de Santa Rosa',
#                   'phone': '+524422149131',
#                   'price': '$',
#                   'rating': 5.0,
#                   'review_count': 1,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/portal-de-santa-rosa-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'erlum-santiago-de-querétaro-2',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'gastropubs',
#                                   'title': 'Gastropubs'}],
#                   'coordinates': {'latitude': 20.5889976,
#                                   'longitude': -100.393993},
#                   'display_phone': '+52 442 212 0522',
#                   'distance': 978.4954104461617,
#                   'id': 'kV32puuCi90hM4fVANk69Q',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9f2Psu_OkNPdZqdj_vnmvQ/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Jose Maria Arteaga 55',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
# ...
#                                'state': 'QUE',
#                                'zip_code': '76160'},
#                   'name': 'San Telmo',
#                   'phone': '+524422481925',
#                   'price': '$$',
#                   'rating': 3.7,
#                   'review_count': 3,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/san-telmo-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'rock-n-ribs-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': 'http://www.rocknribs.mx/menu.html',
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#                   'coordinates': {'latitude': 20.5994832522492,
#                                   'longitude': -100.375738995465},
#                   'display_phone': '+52 442 213 3012',
#                   'distance': 525.7320634191685,
#                   'id': 'zVWXZ8o6ZRCEVXzHdAHrBA',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FJcX8smmnVlmgzoeBCFcTQ/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Blvd. Bernardo Quintana 41',
#                                'address2': 'Col. Pathe',
#                                'address3': '',
#                                'city': 'Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Blvd. Bernardo Quintana 41',
#                                                    'Col. Pathe',
#                                                    '76020 Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76020'},
#                   'name': "Rock n' Ribs",
#                   'phone': '+524422133012',
#                   'price': '$$',
#                   'rating': 2.5,
#                   'review_count': 4,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/rock-n-ribs-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'sinatra-351-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#                   'coordinates': {'latitude': 20.594041,
#                                   'longitude': -100.380331},
#                   'display_phone': '+52 442 168 6592',
#                   'distance': 525.7932030744992,
#                   'id': 'XiEsh0m75m0EeBacMp4O7w',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cQ-VDp7z89mViPzxwlfnTQ/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Av. Circunvalacion 46',
#                                'address2': 'Alta',
#                                'address3': None,
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Av. Circunvalacion 46',
#                                                    'Alta',
#                                                    '76000 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76000'},
#                   'name': 'Sinatra 351',
#                   'phone': '+524421686592',
#                   'price': '$$',
#                   'rating': 4.0,
#                   'review_count': 1,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/sinatra-351-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'tacos-pampas-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#                                  {'alias': 'bbq', 'title': 'Barbeque'}],
#                   'coordinates': {'latitude': 20.5882448663806,
#                                   'longitude': -100.366666764021},
#                   'display_phone': '',
#                   'distance': 1158.2284565375019,
#                   'id': 'wPbwPPUzQhDlXf5AtuX2Vw',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fNL7OE0T2nXCt6gpPlxUOg/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Av. Constituyentes 66',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Av. Constituyentes 66',
#                                                    '76070 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76070'},
#                   'name': 'Tacos Pampas',
#                   'phone': '',
#                   'price': '$',
#                   'rating': 4.3,
#                   'review_count': 6,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/tacos-pampas-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'wings-army-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'tradamerican',
#                                   'title': 'American'}],
#                   'coordinates': {'latitude': 20.5952396,
#                                   'longitude': -100.3744888},
#                   'display_phone': '+52 442 248 4082',
#                   'distance': 150.8633745132117,
#                   'id': 'xCBjYhx7UX3hxR0GmeUC8g',
#                   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Jp8V659znziBeDilSagXDQ/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Calzada de los Arcos',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Calzada de los Arcos',
#                                                    '76020 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76020'},
#                   'name': 'Wings Army',
#                   'phone': '+524422484082',
#                   'price': '$$',
#                   'rating': 1.5,
#                   'review_count': 2,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/wings-army-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'restaurant-bar-el-palomar-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'restaurants',
#                                   'title': 'Restaurants'}],
#                   'coordinates': {'latitude': 20.599859,
#                                   'longitude': -100.384552},
#                   'display_phone': '+52 1003845515',
#                   'distance': 1113.3722627997552,
#                   'id': '_JflgEuJDcO2ptlutOUqsA',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/k4tcxXVq_cpi7WPlckxTFQ/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Privada Damián Carmona 101',
#                                'address2': None,
#                                'address3': None,
#                                'city': 'Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Privada Damián Carmona 101',
#                                                    '76000 Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76000'},
#                   'name': 'Restaurant Bar el Palomar',
#                   'phone': '+521003845515',
#                   'price': '$',
#                   'rating': 4.0,
#                   'review_count': 2,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/restaurant-bar-el-palomar-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'sushi-itto-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#                   'coordinates': {'latitude': 20.59718,
#                                   'longitude': -100.373158},
#                   'display_phone': '+52 442 213 7971',
#                   'distance': 351.27796388697345,
#                   'id': 'cfXMoLzUE4Iet1OdWzrOxw',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xqUl-19LzfICs76H6F4RMA/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Bernardo Quintana 13',
#                                'address2': None,
#                                'address3': None,
#                                'city': 'Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Bernardo Quintana 13',
#                                                    '76020 Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76020'},
#                   'name': 'Sushi Itto',
#                   'phone': '+524422137971',
#                   'price': '$$',
#                   'rating': 2.0,
#                   'review_count': 1,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/sushi-itto-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'}],
#   'region': {'center': {'latitude': 20.59477, 'longitude': -100.37534}},
#   'total': 27},
#  {'businesses': [{'alias': 'la-barbacha-de-los-cuatro-santiago-de-querétaro',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#                   'coordinates': {'latitude': 20.6094532935398,
#                                   'longitude': -100.399491617237},
#                   'display_phone': '+52 442 431 9724',
#                   'distance': 493.57983920252326,
#                   'id': 'exIMLBE1Y_sqtC1cFcSHdg',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wy_yLmA_c_2jb-rDCvXr5g/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Felipe Angeles 154',
#                                'address2': 'Col. España',
#                                'address3': '',
#                                'city': 'Santiago de Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Felipe Angeles 154',
#                                                    'Col. España',
#                                                    '76158 Santiago de '
#                                                    'Querétaro, Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76158'},
#                   'name': 'La Barbacha de los Cuatro',
#                   'phone': '+524424319724',
#                   'price': '$',
#                   'rating': 0.0,
#                   'review_count': 0,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/la-barbacha-de-los-cuatro-santiago-de-quer%C3%A9taro?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'},
#                  {'alias': 'hamburguerzo-querétaro-2',
#                   'attributes': {'business_temp_closed': None,
#                                  'menu_url': None,
#                                  'open24_hours': None,
#                                  'waitlist_reservation': None},
#                   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'}],
#                   'coordinates': {'latitude': 20.6121651940173,
#                                   'longitude': -100.399872978513},
#                   'display_phone': '+52 442 217 4510',
#                   'distance': 370.0106506210618,
#                   'id': 'tbcNYLRY3hs_MOnx3SAv9g',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7zFPhImtlCzu_3fael0TPQ/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': 'Av. Felipe Angeles 101',
#                                'address2': None,
#                                'address3': None,
#                                'city': 'Querétaro',
#                                'country': 'MX',
#                                'display_address': ['Av. Felipe Angeles 101',
#                                                    '76158 Querétaro',
#                                                    'Mexico'],
#                                'state': 'QUE',
#                                'zip_code': '76158'},
#                   'name': 'Hamburguerzo',
#                   'phone': '+524422174510',
#                   'price': '$$',
#                   'rating': 2.0,
#                   'review_count': 2,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/hamburguerzo-quer%C3%A9taro-2?adjust_creative=spfPpmZKXWNKduSGGpkZlg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spfPpmZKXWNKduSGGpkZlg'}],
#   'region': {'center': {'latitude': 20.61194, 'longitude': -100.40342}},
#   'total': 2}]

# %% [markdown]
# ## 2. Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
# Assuming saved_restaurants_list_yelp[1]['businesses'][0] is the dictionary you want to access
business = saved_restaurants_list_yelp[1]['businesses'][0]

categories = business['categories']
distance = business['distance']
id = business['id']
name = business['name']
price = business['price']
rating = business['rating']

print(categories)
print(distance)
print(id)
print(name)
print(price)
print(rating)
# Out:
# [{'alias': 'oaxacan', 'title': 'Oaxacan'}, {'alias': 'yucatan', 'title': 'Yucatan'}]
# 1169.5500257882732
# Y2Iqqe13-n7_60q9ND0vMA
# Tikua Sureste
# $$
# 4.7

# %% [markdown]
# ## 3. Put your parsed results into a DataFrame

# %%
# Retrieve information of interest: name, distance, categories, rating, price and review count.

extracted_data_yelp = []

for entry in saved_restaurants_list_yelp:
    for business in entry['businesses']:
        extracted_data_yelp.append({
            'distance': business['distance'],
            'name': business['name'],
            'categories': business['categories'],
            'price': business['price'],
            'rating': business['rating']
            })

# Creating DataFrame
restaurant_info_yelp_df = pd.DataFrame(extracted_data_yelp)
restaurant_info_yelp_df
# Out:
#         distance                       name  \
# 0     270.080982            Fogon do Brasil
# 1     919.137726                    Josecho
# 2    1001.499627          Karnes en Su Jugo
# 3     989.584691                    Ichiban
# 4     641.412281                       Pawa
# ..           ...                        ...
# 714   150.863375                 Wings Army
# 715  1113.372263  Restaurant Bar el Palomar
# 716   351.277964                 Sushi Itto
# 717   493.579839  La Barbacha de los Cuatro
# 718   370.010651               Hamburguerzo
#
#                                             categories price  rating
# 0       [{'alias': 'brazilian', 'title': 'Brazilian'}]    $$     3.0
# 1    [{'alias': 'wine_bars', 'title': 'Wine Bars'},...  $$$$     5.0
# 2    [{'alias': 'comfortfood', 'title': 'Comfort Fo...    $$     4.8
# 3         [{'alias': 'japanese', 'title': 'Japanese'}]    $$     3.8
# 4    [{'alias': 'japanese', 'title': 'Japanese'}, {...    $$     0.0
# ..                                                 ...   ...     ...
# 714   [{'alias': 'tradamerican', 'title': 'American'}]    $$     1.5
# 715  [{'alias': 'restaurants', 'title': 'Restaurant...     $     4.0
# 716        [{'alias': 'sushi', 'title': 'Sushi Bars'}]    $$     2.0
# 717            [{'alias': 'bbq', 'title': 'Barbeque'}]     $     0.0
# 718       [{'alias': 'hotdogs', 'title': 'Fast Food'}]    $$     2.0
#
# [719 rows x 5 columns]

# %% [markdown]
# # Comparing Results

# %% [markdown]
# ## 1. Which API provided you with more complete data? Provide an explanation.

# %%
restaurant_info_df['name'].value_counts()
# Out:
# name
# Di Vino                            7
# Chinicuil                          7
# Hotel la Casa de la Marquesa       7
# Restaurante 1810                   7
# Breton                             7
#                                   ..
# El Sazón de Papá                   1
# California Pizza Kitchen           1
# Fogon do Brasil Queretaro          1
# Los Idolos                         1
# Angus Butcher House - Queretaro    1
# Name: count, Length: 74, dtype: int64

# %%
restaurant_info_yelp_df['name'].value_counts()
# Out:
# name
# María y Su Bici               18
# Restaurante Bar 1810          17
# El Mesón De Chucho El Roto    17
# Chinicuil                     17
# Café Breton                   17
#                               ..
# Mesón de la Corregidora        1
# El Fogón del Pastor            1
# Karnes en Su Jugo              1
# El Comal Antojitos             1
# Sushi Itto                     1
# Name: count, Length: 100, dtype: int64

# %%
unique_fq_rest = restaurant_info_df.drop_duplicates(subset = ['name']).dropna()
unique_fq_rest
# Out:
#      distance                             name  popularity  price  rating  \
# 0          47         Monosabio Hamburguesería    0.979649    3.0     8.5
# 1         149                 Taqueria Jalisco    0.937276    1.0     7.9
# 2         158                       Los Idolos    0.941187    1.0     7.7
# 3         243        Fogon do Brasil Queretaro    0.989483    2.0     8.2
# 4         598                       Sushi Roll    0.987812    2.0     8.2
# ..        ...                              ...         ...    ...     ...
# 224       436                           Cocono    0.981471    1.0     8.8
# 225       458                         Fisher's    0.995444    3.0     8.6
# 226       498                         La Bocha    0.990963    3.0     8.8
# 227       407          Arrachera's Steak House    0.975055    4.0     7.5
# 228       446  Angus Butcher House - Queretaro    0.980256    4.0     7.9
#
#                                          hours_display
# 0    Tue 13:00-22:00; Wed 13:00-22:30; Thu-Sat 13:0...
# 1                                 Open Daily 0:00-4:00
# 2                 Tue-Sat 12:30-22:00; Sun 12:30-20:00
# 3                 Mon-Sat 13:00-22:00; Sun 13:00-21:00
# 4    Mon-Thu 13:00-23:00; Fri-Sat 13:00-24:00; Sun ...
# ..                                                 ...
# 224               Mon-Sat 13:00-22:00; Sun 13:00-18:00
# 225  Mon-Tue 9:30-21:00; Wed-Sat 9:30-22:00; Sun 9:...
# 226  Mon-Wed 13:00-23:00; Thu-Sat 13:00-23:59; Sun ...
# 227                             Open Daily 12:00-21:00
# 228                                Mon-Fri 13:00-23:59
#
# [67 rows x 6 columns]

# %%
unique_yelp_rest = restaurant_info_yelp_df.drop_duplicates(subset = ['name']).dropna()
unique_yelp_rest
# Out:
#         distance                       name  \
# 0     270.080982            Fogon do Brasil
# 1     919.137726                    Josecho
# 2    1001.499627          Karnes en Su Jugo
# 3     989.584691                    Ichiban
# 4     641.412281                       Pawa
# ..           ...                        ...
# 545   598.271366                   Tonino's
# 546   918.508493          Sante Restaurante
# 547   442.146233  La Barbacha de los Cuatro
# 636   730.597618         El Comal Antojitos
# 716   351.277964                 Sushi Itto
#
#                                             categories price  rating
# 0       [{'alias': 'brazilian', 'title': 'Brazilian'}]    $$     3.0
# 1    [{'alias': 'wine_bars', 'title': 'Wine Bars'},...  $$$$     5.0
# 2    [{'alias': 'comfortfood', 'title': 'Comfort Fo...    $$     4.8
# 3         [{'alias': 'japanese', 'title': 'Japanese'}]    $$     3.8
# 4    [{'alias': 'japanese', 'title': 'Japanese'}, {...    $$     0.0
# ..                                                 ...   ...     ...
# 545  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...    $$     4.3
# 546         [{'alias': 'mexican', 'title': 'Mexican'}]   $$$     4.0
# 547            [{'alias': 'bbq', 'title': 'Barbeque'}]     $     0.0
# 636         [{'alias': 'mexican', 'title': 'Mexican'}]     $     1.7
# 716        [{'alias': 'sushi', 'title': 'Sushi Bars'}]    $$     2.0
#
# [100 rows x 5 columns]

# %%
unique_fq_rest['name'].value_counts()
# Out:
# name
# Monosabio Hamburguesería           1
# La Crécola                         1
# Bogati Pizza                       1
# Maria y Su Bici                    1
# Il Diavolo                         1
#                                   ..
# Sonora Grill - Puerta Victoria     1
# Mirthala                           1
# Fa yian                            1
# La Huerta de Carlota               1
# Angus Butcher House - Queretaro    1
# Name: count, Length: 67, dtype: int64

# %%
unique_yelp_rest['name'].value_counts()
# Out:
# name
# Fogon do Brasil            1
# McDonald's                 1
# Jochadora                  1
# Fiume 37                   1
# Wings Army                 1
#                           ..
# Diktatur                   1
# Wingstop                   1
# Las Brisas                 1
# Trattoria da Pulcinella    1
# Sushi Itto                 1
# Name: count, Length: 100, dtype: int64

# %%
print(f'Yelp Restaurants: {restaurant_info_yelp_df.shape[0]}')
print(f'Foursquare Restaurants: {restaurant_info_df.shape[0]}')
print(f'Yelp Restaurants - No duplicates or NA: {unique_yelp_rest.shape[0]}')
print(f'Foursquare Restaurants - No duplicates or NA: {unique_fq_rest.shape[0]}')
# Out:
# Yelp Restaurants: 719
# Foursquare Restaurants: 241
# Yelp Restaurants - No duplicates or NA: 100
# Foursquare Restaurants - No duplicates or NA: 67

# %% [markdown]
# *The Yelp API resulted in more results in total, almost 3 times more. There was also other information that could have been retrieved that was of more interest that Foursquare didn't have. However, some of that information, like businness hours, were only available with a second get request, that require the businesses 'id'. With the Foursquare, that information was obtained with a single get request.*
#
# *Another thing to consider is that, after dropping all duplicates, the total number of restaurants dropped significantly, this due to several restaurants being included in the list for being near several bike stations. The number of restaurants also dropped because the rows with missing values were no included.*

# %% [markdown]
# ## 2. Get the top 10 restaurants according to their rating

# %% [markdown]
# ### *Top 10 restaurants from Yelp API*

# %%
unique_yelp_rest[['name', 'rating']].sort_values('rating', ascending = False).head(10)
# Out:
#                      name  rating
# 1                 Josecho     5.0
# 22   Portal de Santa Rosa     5.0
# 371             Jochadora     5.0
# 88    Taquería Jalisco II     5.0
# 90             Che Papusa     5.0
# 6            Las Delicias     5.0
# 370              Fiume 37     4.8
# 20          La Charamusca     4.8
# 2       Karnes en Su Jugo     4.8
# 456              Mochomos     4.7

# %% [markdown]
# ### *Top 10 restaurants from Foursquare API*

# %%
unique_fq_rest[['name', 'rating']].sort_values('rating', ascending = False).head(10)
# Out:
#                                name  rating
# 133            Alta Fibra Querétaro     9.2
# 22                   Tikua Sur Este     9.1
# 31   Sonora Grill - Puerta Victoria     9.0
# 223              Habibi Restaurante     9.0
# 136                        Il Duomo     9.0
# 18                La Dulce Compañía     8.9
# 131                      Il Diavolo     8.9
# 175                        Fiume 37     8.9
# 7                        iL Diavolo     8.9
# 226                        La Bocha     8.8
